# %% [markdown]
# # EXERCISE - DATA CLEANUP

# %% [markdown]
# Cleanup list and datetime objects

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': ['Python', 'SQL', 'Machine Learning'], 'job_date': '2024-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': ['Python', 'TensorFlow', 'Deep Learning'], 'job_date': '2024-07-23'},
    {'job_title': 'Data Analyst', 'job_skills': ['Excel', 'SQL', 'Data Visualization'], 'job_date': '2024-06-14'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': ['SQL', 'Power BI', 'Data Visualization'], 'job_date': '2024-08-10'},
    {'job_title': 'Data Engineer', 'job_skills': ['Python', 'SQL', 'ETL'], 'job_date': '2024-09-01'},
    {'job_title': 'Research Scientist', 'job_skills': ['Python', 'Statistics', 'Machine Learning'], 'job_date': '2024-10-05'},
    {'job_title': 'Quantitative Analyst', 'job_skills': ['R', 'Python', 'Data Modeling'], 'job_date': '2024-04-25'},
    {'job_title': 'AI Engineer', 'job_skills': ['Python', 'NLP', 'Machine Learning'], 'job_date': '2024-03-18'},
    {'job_title': 'Data Architect', 'job_skills': ['SQL', 'Database Design', 'Cloud Computing'], 'job_date': '2024-02-11'},
    {'job_title': 'Data Science Intern', 'job_skills': ['Python', 'SQL', 'Data Wrangling'], 'job_date': '2024-01-21'}
]

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2024, 11, 13, 18, 10, 49, 591781)

# %%
test_date = data_science_jobs[0]['job_date']

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2024-05-12 00:00:00

# %%
for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2024, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2024, 7, 23, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['Excel', 'SQL', 'Data Visualization'],
#   'job_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': ['SQL', 'Power BI', 'Data Visualization'],
#   'job_date': datetime.datetime(2024, 8, 10, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'SQL', 'ETL'],
#   'job_date': datetime.datetime(2024, 9, 1, 0, 0)},
#  {'job_title': 'Research Scientist',
#   'job_skills': ['Python', 'Statistics', 'Machine Learning'],
#   'job_date': datetime.datetime(2024, 10, 5, 0, 0)},
#  {'job_title': 'Quantitative Analyst',
# ...

# %%
data_science_jobs = [
    {'job_title': 'Data Scientist', 'job_skills': "['Python', 'SQL', 'Machine Learning']", 'job_date': '2024-05-12'},
    {'job_title': 'Machine Learning Engineer', 'job_skills': "['Python', 'TensorFlow', 'Deep Learning']", 'job_date': '2024-07-23'},
    {'job_title': 'Data Analyst', 'job_skills': "['Excel', 'SQL', 'Data Visualization']", 'job_date': '2024-06-14'},
    {'job_title': 'Business Intelligence Analyst', 'job_skills': "['SQL', 'Power BI', 'Data Visualization']", 'job_date': '2024-08-10'},
    {'job_title': 'Data Engineer', 'job_skills': "['Python', 'SQL', 'ETL']", 'job_date': '2024-09-01'},
    {'job_title': 'Research Scientist', 'job_skills': "['Python', 'Statistics', 'Machine Learning']", 'job_date': '2024-10-05'},
    {'job_title': 'Quantitative Analyst', 'job_skills': "['R', 'Python', 'Data Modeling']", 'job_date': '2024-04-25'},
    {'job_title': 'AI Engineer', 'job_skills': "['Python', 'NLP', 'Machine Learning']", 'job_date': '2024-03-18'},
    {'job_title': 'Data Architect', 'job_skills': "['SQL', 'Database Design', 'Cloud Computing']", 'job_date': '2024-02-11'},
    {'job_title': 'Data Science Intern', 'job_skills': "['Python', 'SQL', 'Data Wrangling']", 'job_date': '2024-01-21'}
]

# %%
import ast

for job in data_science_jobs:
  job['job_date'] = datetime.strptime(job['job_date'], '%Y-%m-%d')
  job['job_skills'] = ast.literal_eval(job['job_skills'])

# %%
data_science_jobs
# Out:
# [{'job_title': 'Data Scientist',
#   'job_skills': ['Python', 'SQL', 'Machine Learning'],
#   'job_date': datetime.datetime(2024, 5, 12, 0, 0)},
#  {'job_title': 'Machine Learning Engineer',
#   'job_skills': ['Python', 'TensorFlow', 'Deep Learning'],
#   'job_date': datetime.datetime(2024, 7, 23, 0, 0)},
#  {'job_title': 'Data Analyst',
#   'job_skills': ['Excel', 'SQL', 'Data Visualization'],
#   'job_date': datetime.datetime(2024, 6, 14, 0, 0)},
#  {'job_title': 'Business Intelligence Analyst',
#   'job_skills': ['SQL', 'Power BI', 'Data Visualization'],
#   'job_date': datetime.datetime(2024, 8, 10, 0, 0)},
#  {'job_title': 'Data Engineer',
#   'job_skills': ['Python', 'SQL', 'ETL'],
#   'job_date': datetime.datetime(2024, 9, 1, 0, 0)},
#  {'job_title': 'Research Scientist',
#   'job_skills': ['Python', 'Statistics', 'Machine Learning'],
#   'job_date': datetime.datetime(2024, 10, 5, 0, 0)},
#  {'job_title': 'Quantitative Analyst',
# ...

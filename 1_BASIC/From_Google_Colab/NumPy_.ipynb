# %%
import random

salary_list = [random.randint(50000, 100000) for _ in range(10_000_000)]

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 3.68 s ± 590 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 637 ms ± 154 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
my_array = np.array([1, 2, 3, 4, 5])

# %%
my_array.mean()
# Out:
# 3.0

# %%
# Job titles
job_titles = np.array(['Data Analyst', 'Data Scientist', 'Database Manager', 'Biostatistician', 'unemployed'])

# Basic salaries
base_salaries = np.array([50_000, 70_000, 100_000, 120_000, np.nan])

# Bonus rates
bonus_rates = np.array([.2, .4, .6, .8, np.nan])

# %%
total_salaries = base_salaries * (1 + bonus_rates)

total_salaries
# Out:
# array([ 60000.,  98000., 160000., 216000.,     nan])

# %%
np.nanmean(total_salaries)
# Out:
# 133500.0
